# %% [markdown]
# $$
# \Delta \frac{-1}{\left|\boldsymbol{r}-\boldsymbol{r}^{\prime}\right|}=\operatorname{div} \operatorname{grad} \frac{-1}{\left|\boldsymbol{r}-\boldsymbol{r}^{\prime}\right|}=\operatorname{div} \frac{\boldsymbol{r}-\boldsymbol{r}^{\prime}}{\left|\boldsymbol{r}-\boldsymbol{r}^{\prime}\right|^3}
# $$

# %% [markdown]
# ### Chatgpt:

# %% [markdown]
# The expression you provided is related to the Laplacian of the Green's function for the three-dimensional Laplace equation, often encountered in electrostatics and gravitational potential problems. Let's break it down step by step:
#
# Given:
# $$\Delta \frac{-1}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|}\$$
#
# This expression represents the Laplacian often (denoted by $\Delta$) of the inverse distance between two vectors $\boldsymbol{r}$ and $\boldsymbol{r}^{\prime}$.
#
# Now, let's calculate it step by step:
#
# 1. Gradient of $\frac{-1}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|}$:
#    $\nabla \left(\frac{-1}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|}\right)$
#
# To find the gradient, we can use the chain rule and the properties of the absolute value:
#
# $\nabla \left(\frac{-1}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|}\right) = \frac{\partial}{\partial \boldsymbol{r}} \left(\frac{-1}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|}\right)$
#
# Now, you can apply the chain rule and the fact that the gradient of the absolute value of a vector is the vector itself divided by its magnitude:
#
# $\nabla \left(\frac{-1}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|}\right) = \frac{\boldsymbol{r}-\boldsymbol{r}^{\prime}}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|^3}$
#
# 2. Divergence of the gradient:
#    $\operatorname{div}\left(\nabla \left(\frac{-1}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|}\right)\right)$
#
# The divergence of this gradient can be calculated as follows:
#
# $\operatorname{div}\left(\nabla \left(\frac{-1}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|}\right)\right) = \nabla \cdot \left(\frac{\boldsymbol{r}-\boldsymbol{r}^{\prime}}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|^3}\right)$
#
# Now, you can compute the divergence of the vector:
#
# $\nabla \cdot \left(\frac{\boldsymbol{r}-\boldsymbol{r}^{\prime}}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|^3}\right) = \frac{\partial}{\partial x} \left(\frac{\boldsymbol{r}-\boldsymbol{r}^{\prime}}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|^3}\right)_x + \frac{\partial}{\partial y} \left(\frac{\boldsymbol{r}-\boldsymbol{r}^{\prime}}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|^3}\right)_y + \frac{\partial}{\partial z} \left(\frac{\boldsymbol{r}-\boldsymbol{r}^{\prime}}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|^3}\right)_z$
#
# This gives you the expression you provided:
#
# $\operatorname{div}\left(\nabla \left(\frac{-1}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|}\right)\right) = \operatorname{div}\left(\frac{\boldsymbol{r}-\boldsymbol{r}^{\prime}}{|\boldsymbol{r}-\boldsymbol{r}^{\prime}|^3}\right)$

# %% [markdown]
# ![image.png](attachment:image.png)
